# %%
import numpy as np

# %% [markdown]
# # После импорта библиотеки демонстрируем массивы

# %%
nums_array = np.array([1, 2, 3, 5])
nums_array
# Out:
# array([1, 2, 3, 5])

# %%
zeros_array = np.zeros(5)
zeros_array
# Out:
# array([0., 0., 0., 0., 0.])

# %%
ones_array = np.ones(5)
ones_array
# Out:
# array([1., 1., 1., 1., 1.])

# %%
nums_arange = np.arange(5)
nums_arange
# Out:
# array([0, 1, 2, 3, 4])

# %% [markdown]
# # выводим форму (shape) и тип данных с помощью dtype

# %%
nums_arange.shape
# Out:
# (5,)

# %%
nums_arange.dtype
# Out:
# dtype('int64')

# %% [markdown]
# # получаем отдельный элемент и извлекаем подмассив с помощью среза

# %%
nums_arange[4]
# Out:
# np.int64(4)

# %%
nums_arange[3:10]
# Out:
# array([3, 4])

# %% [markdown]
# # поэлементо складываем и умноженаем массивы

# %%
a = np.array([1, 2])
b = np.array([3, 5])
a+b
# Out:
# array([4, 7])

# %%
a*b
# Out:
# array([ 3, 10])

# %% [markdown]
# # вычисляем среднюю величину (mean)

# %%
(a+b).mean()
# Out:
# np.float64(5.5)
